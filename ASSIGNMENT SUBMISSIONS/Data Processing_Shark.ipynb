# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import ExcelFile

# %%
dfshark = pd.read_excel("GSAF5-1.xls",sep='\s*,\s*')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-5cbd6318d5d1> in <module>
# ----> 1 dfshark = pd.read_excel("GSAF5-1.xls",sep='\s*,\s*')
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ...

# %%
dfshark.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-160f0b68637c> in <module>
# ----> 1 dfshark.info()
#
# NameError: name 'dfshark' is not defined

# %%
dfshark
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-18c503a6a262> in <module>
# ----> 1 dfshark
#
# NameError: name 'dfshark' is not defined

# %%
dfshark.isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-95b95069d27b> in <module>
# ----> 1 dfshark.isnull()
#
# NameError: name 'dfshark' is not defined

# %%
dfshark.isnull().sum()
# Out:
# Case Number               17021
# Date                      19309
# Year                      19311
# Type                      19313
# Country                   19359
# Area                      19772
# Location                  19856
# Activity                  19859
# Name                      19519
# Sex                       19874
# Age                       22174
# Injury                    19337
# Fatal (Y/N)               19855
# Time                      22696
# Species                   22215
# Investigator or Source    19326
# pdf                       19309
# href formula              19311
# href                      19309
# Case Number.1             19309
# Case Number.2             19309
# original order            19309
# Unnamed: 22               25759
# Unnamed: 23               25758
# dtype: int64

# %%
dfshark.isna().sum()
# Out:
# Case Number               17021
# Date                      19309
# Year                      19311
# Type                      19313
# Country                   19359
# Area                      19772
# Location                  19856
# Activity                  19859
# Name                      19519
# Sex                       19874
# Age                       22174
# Injury                    19337
# Fatal (Y/N)               19855
# Time                      22696
# Species                   22215
# Investigator or Source    19326
# pdf                       19309
# href formula              19311
# href                      19309
# Case Number.1             19309
# Case Number.2             19309
# original order            19309
# Unnamed: 22               25759
# Unnamed: 23               25758
# dtype: int64

# %%
dfshark['Time'].unique()
# Out:
# array(['11h55', '09h00', '08h00', '11h00', '19h30', '15h00', '16h00',
#        '15h30', nan, '13h30', '18h30', '16h30', 'Morning', '07h30',
#        '10h30', '17h30', '14h00', '13h00', '12h20', '08h48', '08h30',
#        '16h21', '16h26', '18h45', '17h45', 'Night', '01h00', '10h00',
#        '12h30', '03h00', '06h40', '13h40', '06h15', '09h15', 'Evening',
#        '11h30', '09h30', '11h20', '07h15', '17h00', 'Before 10h00',
#        '06h50', '08h40', '06h45', 'Early afternoon', '07h00', '18h00',
#        '12h00', 'Afternoon', '06h55', '13h42', '13h45', '13h15', '09h29',
#        '20h00', '10h47', 'Sunset', '11h15', '14h11', '15h40', '15h35',
#        '14h40', '14h00  -15h00', '07h45', 'Late afternoon', '08h15',
#        '10h40', '16h50', '21h50', '09h40', '17h35', '19h00, Dusk',
#        '15h01', '23h30', '14h30', '06h00', '10h44', '13h19', 'Midday',
#        '10h45', '11h45', '15h45', 'Shortly before 12h00', '17h34',
# ...

# %%
from datetime import date

# %%
timestamp = date.fromtimestamp(1326244364)
print("Date =", timestamp)
# Out:
# Date = 2012-01-10

# %%
dfshark.shape
# Out:
# (25760, 24)

# %%
df=dfshark[np.logical_and(dfshark.Country=='USA',dfshark.Year>1998)]
df
# Out:
#        Case Number                  Date    Year          Type Country  \
# 0       2019.08.27           27-Aug-2019  2019.0      Provoked     USA
# 1       2019.08.21           21-Aug-2019  2019.0    Unprovoked     USA
# 2       2019.08.20           20-Aug-2019  2019.0    Unprovoked     USA
# 3       2019.08.16           16-Aug-2019  2019.0    Unprovoked     USA
# 4       2019.08.11           11-Aug-2019  2019.0    Unprovoked     USA
# 5       2019.08.04           04-Aug-2019  2019.0    Unprovoked     USA
# 6     2019.08.03.c           03-Aug-2019  2019.0    Unprovoked     USA
# 7     2019.08.03.b           03-Aug-2019  2019.0    Unprovoked     USA
# 8     2019.08.03.a           03-Aug-2019  2019.0    Unprovoked     USA
# 9       2019.07.30           30-Jul-2019  2019.0      Provoked     USA
# 10      2019.07.29           29-Jul-2019  2019.0    Unprovoked     USA
# 12    2019.07.27.b           27-Jul-2019  2019.0    Unprovoked     USA
# ...

# %%
df.head()
# Out:
#   Case Number         Date    Year        Type Country     Area  \
# 0  2019.08.27  27-Aug-2019  2019.0    Provoked     USA  Florida
# 1  2019.08.21  21-Aug-2019  2019.0  Unprovoked     USA  Florida
# 2  2019.08.20  20-Aug-2019  2019.0  Unprovoked     USA   Hawaii
# 3  2019.08.16  16-Aug-2019  2019.0  Unprovoked     USA  Florida
# 4  2019.08.11  11-Aug-2019  2019.0  Unprovoked     USA   Hawaii
#
#                                           Location  Activity  \
# 0                 New Smyrna Beach, Volusia County   Surfing
# 1                  Fort Lauderdale, Broward County    Wading
# 2  Napoopoo Park in Kealakekua Bay, The Big Island  Swimming
# 3                 New Smyrna Beach, Volusia County    Wading
# 4                               Makaha Beach, Oahu   Surfing
#
#                  Name Sex      ...              Species   \
# 0        Donald Walsh    M     ...            6.5' shark
# 1  Christian Mariani     M     ...                   NaN
# ...

# %%
df['Species'].unique()
# Out:
# array(["6.5' shark", nan, "10' to 12' shark", "Blacktip shark, 5' ",
#        'Blacktip or Spinner shark', 'Sandtiger shark', 'shark pup',
#        "Bull shark, 4' to 5'",
#        'Shark involvement unconfirmed but considered probable',
#        "8' shark", 'White shark', 'Tiger shark', 'Cookiecutter shark',
#        "12' shark", "4' shark", 'Spinner shark', 'Bull shark',
#        'White shark, 4.6m', "3' to 4' shark", "White shark, 17' female",
#        "White shark, 11'", "Tiger shark, 10' to 12'", "5' to 8' shark",
#        "Said to involve a bull shark, 5' to 6'",
#        'Said to involve a blacktip shark', 'Salmon shark, juvenile',
#        'Injury most likely caused by barracuda, not a shark',
#        'Nurse shark', "Lemon shark, 3'", "Bull shark, 6'",
#        "Sandtiger shark'", "6' shark", "Tiger shark, 12'",
#        'White shark, 4.6 m', 'Spinner shark, 4 to 5 feet',
#        'Tiger shark, 8 to 10 feet', "5' shark", 'Questionable',
# ...

# %%
df=df['Species'].fillna(df['Species'].mode())

# %%
df["Species"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-160-0045cad78790> in <module>
# ----> 1 df["Species"]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3116         try:
# ...

# %%
df.columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-161-46738d2056d9> in <module>
# ----> 1 df.columns.tolist()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370         if (name in self._internal_names_set or name in self._metadata or
#    4371                 name in self._accessors):
# -> 4372             return object.__getattribute__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
df['Species '].value_counts()
# Out:
# Shark involvement not confirmed                                              37
# 4' shark                                                                     30
# White shark                                                                  30
# 4' to 5' shark                                                               21
# 3' shark                                                                     18
# Tiger shark                                                                  17
# 3' to 4' shark                                                               17
# Bull shark                                                                   13
# 5' shark                                                                     12
# 6' shark                                                                     10
# No shark involvement                                                          7
# Unidentified species                                                          7
# ...

# %%
df['Species '].fillna(df['Species '].mode())
# Out:
# 0                                              6.5' shark
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                        10' to 12' shark
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                     Blacktip shark, 5'
# 10                                                    NaN
# 12                                                    NaN
# 13                              Blacktip or Spinner shark
# 14                                        Sandtiger shark
# 15                                                    NaN
# 17                                              shark pup
# ...
